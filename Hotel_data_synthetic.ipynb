# %%
import pandas as pd

# %%
#df1 = pd.read_csv('Hotel.csv')
df2 = pd.read_csv('merged_rates2.csv')
#df3 = pd.read_csv('dump.csv')
df4 = pd.read_csv('TM-UAT data.csv')
# Out:
# /tmp/ipykernel_41490/2161500613.py:2: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2 = pd.read_csv('merged_rates2.csv')

# %%
df4.tail()
# Out:
#             id  bookingvalue  hotelcode                hotelname  \
# 15151  5186983        445.21       7324     Aloft Boston Seaport
# 15152  5193410        117.75       6134                Hotel TM2
# 15153  5190976        341.80       9173  Test TravelClick Hotel1
# 15154  5190596        121.00       9174         New TravelClick3
# 15155  5184238        752.00       7743           Queen Anne Inn
#
#                 city country  totalrooms  availablerooms  profit
# 15151         Boston     USA       999.0           934.0   106.0
# 15152      Las Vegas     USA       100.0            98.0    18.0
# 15153  New York City     USA        20.0             0.0   102.0
# 15154         Boston     USA       100.0            97.0    34.0
# 15155        Chatham     USA         5.0             3.0   162.5

# %%
df2.tail(2)
# Out:
#                          Search DateTime Checkin Date  \
# 845714  2022-09-09T18:05:36.160304+00:00   2022-09-09
# 845715  2022-09-09T18:05:36.160304+00:00   2022-09-09
#
#                                             Property Name  \
# 845714                     Days Inn by Wyndham Alexandria
# 845715  Extended Stay America Suites - Washington, DC ...
#
#                                                 Room Type Room Rate  \
# 845714        Double Room - Disability Access/Non-Smoking     US$84
# 845715  Queen studio with 1 Queen Bed - Disability Acc...    US$105
#
#                                      Location Desc  \
# 845714  AlexandriaShow on map5.1 miles from centre
# 845715    AlexandriaShow on map5 miles from centre
#
#                                                Other Info Unnamed: 7
# 845714  Double Room - Disability Access/Non-Smoking1 d...        NaN
# 845715  Queen studio with 1 Queen Bed - Disability Acc...        NaN

# %%
len(df2['Property Name'].unique())
# Out:
# 6700

# %%
len(df4['hotelname'].unique())
# Out:
# 545

# %%
df2.tail(2)
# Out:
#                          Search DateTime Checkin Date  \
# 845714  2022-09-09T18:05:36.160304+00:00   2022-09-09
# 845715  2022-09-09T18:05:36.160304+00:00   2022-09-09
#
#                                             Property Name  \
# 845714                     Days Inn by Wyndham Alexandria
# 845715  Extended Stay America Suites - Washington, DC ...
#
#                                                 Room Type Room Rate  \
# 845714        Double Room - Disability Access/Non-Smoking     US$84
# 845715  Queen studio with 1 Queen Bed - Disability Acc...    US$105
#
#                                      Location Desc  \
# 845714  AlexandriaShow on map5.1 miles from centre
# 845715    AlexandriaShow on map5 miles from centre
#
#                                                Other Info Unnamed: 7
# 845714  Double Room - Disability Access/Non-Smoking1 d...        NaN
# 845715  Queen studio with 1 Queen Bed - Disability Acc...        NaN

# %%
hotel_list = df4['hotelname'].unique().tolist()
scrape_hotel_list = df2['Property Name'].unique().tolist()

# %%
len(scrape_hotel_list)
# Out:
# 6700

# %%
len(hotel_list)
# Out:
# 545

# %%
from collections import Counter

# %%
c1 = Counter(scrape_hotel_list)
c2 = Counter(hotel_list)

# %%
common_items = c1 & c2
common_count = len(common_items)
total_count = len(scrape_hotel_list) + len(hotel_list)
similarity_percentage = (common_count / total_count) * 100

# %%
print(similarity_percentage)
# Out:
# 0.22084195997239478

# %%
from nltk.metrics.distance import jaccard_distance

# %%
list1 = scrape_hotel_list
list2 = hotel_list

# %%
type(list2[0])
# Out:
# str

# %%
list1 = list(map(str, list1))
list2 = list(map(str, list2))

# %%
def jaccard_similarity(sentence1, sentence2):
    return 1 - jaccard_distance(set(sentence1.split()), set(sentence2.split()))

# %%
similar_sentences = []
threshold = 0.5
for sentence1 in list1:
    for sentence2 in list2:
        similarity = jaccard_similarity(sentence1, sentence2)
        if similarity > threshold:
            similar_sentences.append((sentence1, sentence2, similarity))

# %%
type(similar_sentences[0])
# Out:
# tuple

# %%
df = pd.DataFrame(similar_sentences,columns=['Scrape_hotel_Name','Hotel_name','Similarity'])

# %%
df
# Out:
#                                      Scrape_hotel_Name  \
# 0                      Millennium Biltmore Los Angeles
# 1                    Hampton Inn & Suites Santa Monica
# 2                     Best Western Plus Commerce Hotel
# 3                 Best Western Plus Sunset Plaza Hotel
# 4                    Best Western Plus Dragon Gate Inn
# ..                                                 ...
# 115  Hampton Inn & Suites Orlando North Altamonte S...
# 116  Hampton Inn & Suites Orlando North Altamonte S...
# 117                                       Menger Hotel
# 118                                         Queen Anne
# 119                                   Inn at the Opera
#
#                                  Hotel_name  Similarity
# 0     Millennium Biltmore Hotel Los Angeles    0.800000
# 1               Hampton Inn & Suites Mystic    0.571429
# 2       Best Western Plus Sonora Oaks Hotel    0.571429
# 3            Best Western Royal Plaza Hotel    0.571429
# 4         Best Western Plus Dragon Gate Inn    1.000000
# ..                                      ...         ...
# 115       Hampton Inn & Suites North Conway    0.555556
# 116  Hampton Inn & Suites Bakersfield North    0.555556
# 117                            Menger Hotel    1.000000
# 118                          Queen Anne Inn    0.666667
# 119                        Inn at the Tides    0.600000
#
# [120 rows x 3 columns]

# %%
df['Similarity'].max()
# Out:
# 1.0

# %%
df['Similarity'].min()
# Out:
# 0.5454545454545454

# %%
df4.head(2)
# Out:
#         id  bookingvalue  hotelcode                       hotelname  \
# 0  5186967        367.16       7889                   The Bostonian
# 1  5182026        180.37       8239  Marriott Philadelphia Downtown
#
#            city country  totalrooms  availablerooms  profit
# 0        Boston     USA       999.0           997.0    87.2
# 1  Philadelphia     USA       999.0           993.0    45.0

# %%
df2.tail(2)
# Out:
#                          Search DateTime Checkin Date  \
# 845714  2022-09-09T18:05:36.160304+00:00   2022-09-09
# 845715  2022-09-09T18:05:36.160304+00:00   2022-09-09
#
#                                             Property Name  \
# 845714                     Days Inn by Wyndham Alexandria
# 845715  Extended Stay America Suites - Washington, DC ...
#
#                                                 Room Type Room Rate  \
# 845714        Double Room - Disability Access/Non-Smoking     US$84
# 845715  Queen studio with 1 Queen Bed - Disability Acc...    US$105
#
#                                      Location Desc  \
# 845714  AlexandriaShow on map5.1 miles from centre
# 845715    AlexandriaShow on map5 miles from centre
#
#                                                Other Info Unnamed: 7
# 845714  Double Room - Disability Access/Non-Smoking1 d...        NaN
# 845715  Queen studio with 1 Queen Bed - Disability Acc...        NaN

# %%
len(df2['Room Type'].unique())
# Out:
# 3142

# %%
hotel_df = df2.loc[df2['Property Name'] == 'Millennium Biltmore Los Angeles']

# %%
hotel_df.head()
# Out:
#                 Search DateTime Checkin Date                    Property Name  \
# 70    2022-10-04T13:00:00+00:00    10/4/2022  Millennium Biltmore Los Angeles
# 134   2022-10-04T13:00:00+00:00    10/4/2022  Millennium Biltmore Los Angeles
# 158   2022-10-04T13:00:00+00:00    10/4/2022  Millennium Biltmore Los Angeles
# 8552  2022-10-05T00:15:00+00:00    10/5/2022  Millennium Biltmore Los Angeles
# 8602  2022-10-05T00:15:00+00:00    10/5/2022  Millennium Biltmore Los Angeles
#
#              Room Type Room Rate  \
# 70    Deluxe King Room       NaN
# 134   Deluxe King Room    US$166
# 158   Deluxe King Room    US$166
# 8552  Deluxe King Room       NaN
# 8602  Deluxe King Room       NaN
#
#                                           Location Desc  \
# 70    Downtown Los Angeles, Los AngelesShow on map0....
# 134   Downtown Los Angeles, Los AngelesShow on map0....
# 158   Downtown Los Angeles, Los AngelesShow on map0....
# 8552  Downtown Los Angeles, Los AngelesShow on map0....
# 8602  Downtown Los Angeles, Los AngelesShow on map0....
#
#                                     Other Info Unnamed: 7
# 70    Deluxe King Room1 extra-large double bed        NaN
# 134   Deluxe King Room1 extra-large double bed        NaN
# 158   Deluxe King Room1 extra-large double bed        NaN
# 8552  Deluxe King Room1 extra-large double bed        NaN
# 8602  Deluxe King Room1 extra-large double bed        NaN

# %%
hotel_df = df1.loc[df1['hotelname'] == 'Grand Hotel']

# %%
hotel_df
# Out:
#             id  hotelcode    hotelname
# 2672   5186493       7474  Grand Hotel
# 9971   5181871       7474  Grand Hotel
# 13776  5176444       7474  Grand Hotel

# %%
df4.head()
# Out:
#         id  bookingvalue  hotelcode                       hotelname  \
# 0  5186967        367.16       7889                   The Bostonian
# 1  5182026        180.37       8239  Marriott Philadelphia Downtown
# 2  5171782        267.81       8419                      The Landon
# 3  5179830        274.77       7067            Hyannis Harbor Hotel
# 4  5185869        179.75       7859                  Monterey Tides
#
#                  city country  totalrooms  availablerooms  profit
# 0              Boston     USA       999.0           997.0   87.20
# 1        Philadelphia     USA       999.0           993.0   45.00
# 2  Bay Harbor Islands     USA       999.0           998.0   60.00
# 3             Hyannis     USA         3.0             2.0   60.00
# 4            Monterey     USA         1.0             0.0   34.22

# %%
scrape_hotel_list_new =df['Scrape_hotel_Name'].tolist()
hotel_list_new = df['Scrape_hotel_Name'].tolist()

# %%
scrape_hotel_df = df2.loc[df2['Property Name'].isin(scrape_hotel_list_new)]
hotel_df = df4.loc[df4['hotelname'].isin(hotel_list_new)]

# %%
hotel_df.head()
# Out:
#          id  bookingvalue  hotelcode                  hotelname         city  \
# 9   5188517        846.92       9084       The Revolution Hotel       Boston
# 22  5190423        225.71       7199           Hotel Monteleone  New Orleans
# 23  5187241        438.78       7465  Mardi Gras Hotel & Casino    Las Vegas
# 27  5176440       1192.11       7049        Copley Square Hotel       Boston
# 36  5192847       5854.64       7199           Hotel Monteleone  New Orleans
#
#    country  totalrooms  availablerooms  profit
# 9      USA       999.0           996.0   200.0
# 22     USA       999.0           998.0    56.0
# 23     USA       999.0           998.0   102.0
# 27     USA       999.0           996.0   320.0
# 36     USA       999.0           995.0  1449.0

# %%
scrape_hotel_df =scrape_hotel_df.reset_index()
scrape_hotel_df
# Out:
#         index                   Search DateTime Checkin Date  \
# 0          70         2022-10-04T13:00:00+00:00    10/4/2022
# 1         134         2022-10-04T13:00:00+00:00    10/4/2022
# 2         151         2022-10-04T13:00:00+00:00    10/4/2022
# 3         158         2022-10-04T13:00:00+00:00    10/4/2022
# 4         173         2022-10-04T13:00:00+00:00    10/4/2022
# ...       ...                               ...          ...
# 24411  845384  2022-09-09T18:05:36.160304+00:00   2022-09-09
# 24412  845483  2022-09-09T18:05:36.160304+00:00   2022-09-09
# 24413  845507  2022-09-09T18:05:36.160304+00:00   2022-09-09
# 24414  845597  2022-09-09T18:05:36.160304+00:00   2022-09-09
# 24415  845622  2022-09-09T18:05:36.160304+00:00   2022-09-09
#
#                                          Property Name  \
# 0                      Millennium Biltmore Los Angeles
# 1                      Millennium Biltmore Los Angeles
# 2                    Hampton Inn & Suites Santa Monica
# 3                      Millennium Biltmore Los Angeles
# 4                    Hampton Inn & Suites Santa Monica
# ...                                                ...
# 24411            Best Western Plus Roland Inn & Suites
# 24412                     Best Western Plus Fiesta Inn
# 24413  Best Western Plus San Antonio East Inn & Suites
# 24414  Best Western Plus San Antonio East Inn & Suites
# 24415  Best Western Plus San Antonio East Inn & Suites
#
#                                                Room Type Room Rate  \
# 0                                       Deluxe King Room       NaN
# 1                                       Deluxe King Room    US$166
# 2                                King Room - Non-Smoking    US$279
# 3                                       Deluxe King Room    US$166
# 4                                King Room - Non-Smoking    US$279
# ...                                                  ...       ...
# 24411                     Queen Room with Two Queen Beds    US$134
# 24412                                          King Room    US$100
# 24413  King Room with Bath Tub - Mobility Accessible/...    US$120
# 24414  King Room with Bath Tub - Mobility Accessible/...    US$120
# 24415  King Room with Bath Tub - Mobility Accessible/...    US$120
#
#                                            Location Desc  \
# 0      Downtown Los Angeles, Los AngelesShow on map0....
# 1      Downtown Los Angeles, Los AngelesShow on map0....
# 2      Santa Monica, Los AngelesShow on map14.4 miles...
# 3      Downtown Los Angeles, Los AngelesShow on map0....
# 4      Santa Monica, Los AngelesShow on map14.4 miles...
# ...                                                  ...
# 24411  East San Antonio, San AntonioShow on map3.4 mi...
# 24412  Northwest San Antonio, San AntonioShow on map1...
# 24413       San AntonioShow on map10.9 miles from centre
# 24414       San AntonioShow on map10.9 miles from centre
# 24415       San AntonioShow on map10.9 miles from centre
#
#                                               Other Info Unnamed: 7
# 0               Deluxe King Room1 extra-large double bed        NaN
# 1               Deluxe King Room1 extra-large double bed        NaN
# 2      King Room - Non-Smoking1 extra-large double be...        NaN
# 3               Deluxe King Room1 extra-large double bed        NaN
# 4      King Room - Non-Smoking1 extra-large double be...        NaN
# ...                                                  ...        ...
# 24411  Queen Room with Two Queen Beds2 large double b...        NaN
# 24412  King Room1 extra-large double bedBreakfast inc...        NaN
# 24413  King Room with Bath Tub - Mobility Accessible/...        NaN
# 24414  King Room with Bath Tub - Mobility Accessible/...        NaN
# 24415  King Room with Bath Tub - Mobility Accessible/...        NaN
#
# [24416 rows x 9 columns]

# %%
df.head(3)
# Out:
#                    Scrape_hotel_Name                             Hotel_name  \
# 0    Millennium Biltmore Los Angeles  Millennium Biltmore Hotel Los Angeles
# 1  Hampton Inn & Suites Santa Monica            Hampton Inn & Suites Mystic
# 2   Best Western Plus Commerce Hotel    Best Western Plus Sonora Oaks Hotel
#
#    Similarity
# 0    0.800000
# 1    0.571429
# 2    0.571429

# %%
scrape_hotel_df.head(3)
# Out:
#    index            Search DateTime Checkin Date  \
# 0     70  2022-10-04T13:00:00+00:00    10/4/2022
# 1    134  2022-10-04T13:00:00+00:00    10/4/2022
# 2    151  2022-10-04T13:00:00+00:00    10/4/2022
#
#                        Property Name                Room Type Room Rate  \
# 0    Millennium Biltmore Los Angeles         Deluxe King Room       NaN
# 1    Millennium Biltmore Los Angeles         Deluxe King Room    US$166
# 2  Hampton Inn & Suites Santa Monica  King Room - Non-Smoking    US$279
#
#                                        Location Desc  \
# 0  Downtown Los Angeles, Los AngelesShow on map0....
# 1  Downtown Los Angeles, Los AngelesShow on map0....
# 2  Santa Monica, Los AngelesShow on map14.4 miles...
#
#                                           Other Info Unnamed: 7
# 0           Deluxe King Room1 extra-large double bed        NaN
# 1           Deluxe King Room1 extra-large double bed        NaN
# 2  King Room - Non-Smoking1 extra-large double be...        NaN

# %%
hotel_df.head()
# Out:
#          id  bookingvalue  hotelcode                  hotelname         city  \
# 9   5188517        846.92       9084       The Revolution Hotel       Boston
# 22  5190423        225.71       7199           Hotel Monteleone  New Orleans
# 23  5187241        438.78       7465  Mardi Gras Hotel & Casino    Las Vegas
# 27  5176440       1192.11       7049        Copley Square Hotel       Boston
# 36  5192847       5854.64       7199           Hotel Monteleone  New Orleans
#
#    country  totalrooms  availablerooms  profit
# 9      USA       999.0           996.0   200.0
# 22     USA       999.0           998.0    56.0
# 23     USA       999.0           998.0   102.0
# 27     USA       999.0           996.0   320.0
# 36     USA       999.0           995.0  1449.0

# %%
merged_df = scrape_hotel_df.merge(df, left_on='Property Name', right_on='Scrape_hotel_Name', how='left')

# %%
hotel_df.head(2)
# Out:
#          id  bookingvalue  hotelcode             hotelname         city  \
# 9   5188517        846.92       9084  The Revolution Hotel       Boston
# 22  5190423        225.71       7199      Hotel Monteleone  New Orleans
#
#    country  totalrooms  availablerooms  profit
# 9      USA       999.0           996.0   200.0
# 22     USA       999.0           998.0    56.0

# %%
merged_df_1 = merged_df.merge(hotel_df,  left_on='Property Name', right_on='hotelname', how='left')

# %%
merged_df_1
# Out:
#          index                   Search DateTime Checkin Date  \
# 0           70         2022-10-04T13:00:00+00:00    10/4/2022
# 1          134         2022-10-04T13:00:00+00:00    10/4/2022
# 2          151         2022-10-04T13:00:00+00:00    10/4/2022
# 3          158         2022-10-04T13:00:00+00:00    10/4/2022
# 4          173         2022-10-04T13:00:00+00:00    10/4/2022
# ...        ...                               ...          ...
# 268711  845483  2022-09-09T18:05:36.160304+00:00   2022-09-09
# 268712  845483  2022-09-09T18:05:36.160304+00:00   2022-09-09
# 268713  845507  2022-09-09T18:05:36.160304+00:00   2022-09-09
# 268714  845597  2022-09-09T18:05:36.160304+00:00   2022-09-09
# 268715  845622  2022-09-09T18:05:36.160304+00:00   2022-09-09
#
#                                           Property Name  \
# 0                       Millennium Biltmore Los Angeles
# 1                       Millennium Biltmore Los Angeles
# 2                     Hampton Inn & Suites Santa Monica
# 3                       Millennium Biltmore Los Angeles
# 4                     Hampton Inn & Suites Santa Monica
# ...                                                 ...
# 268711                     Best Western Plus Fiesta Inn
# 268712                     Best Western Plus Fiesta Inn
# 268713  Best Western Plus San Antonio East Inn & Suites
# 268714  Best Western Plus San Antonio East Inn & Suites
# 268715  Best Western Plus San Antonio East Inn & Suites
#
#                                                 Room Type Room Rate  \
# 0                                        Deluxe King Room       NaN
# 1                                        Deluxe King Room    US$166
# 2                                 King Room - Non-Smoking    US$279
# 3                                        Deluxe King Room    US$166
# 4                                 King Room - Non-Smoking    US$279
# ...                                                   ...       ...
# 268711                                          King Room    US$100
# 268712                                          King Room    US$100
# 268713  King Room with Bath Tub - Mobility Accessible/...    US$120
# 268714  King Room with Bath Tub - Mobility Accessible/...    US$120
# 268715  King Room with Bath Tub - Mobility Accessible/...    US$120
#
#                                             Location Desc  \
# 0       Downtown Los Angeles, Los AngelesShow on map0....
# 1       Downtown Los Angeles, Los AngelesShow on map0....
# 2       Santa Monica, Los AngelesShow on map14.4 miles...
# 3       Downtown Los Angeles, Los AngelesShow on map0....
# 4       Santa Monica, Los AngelesShow on map14.4 miles...
# ...                                                   ...
# 268711  Northwest San Antonio, San AntonioShow on map1...
# 268712  Northwest San Antonio, San AntonioShow on map1...
# 268713       San AntonioShow on map10.9 miles from centre
# 268714       San AntonioShow on map10.9 miles from centre
# 268715       San AntonioShow on map10.9 miles from centre
#
#                                                Other Info Unnamed: 7  \
# 0                Deluxe King Room1 extra-large double bed        NaN
# 1                Deluxe King Room1 extra-large double bed        NaN
# 2       King Room - Non-Smoking1 extra-large double be...        NaN
# 3                Deluxe King Room1 extra-large double bed        NaN
# 4       King Room - Non-Smoking1 extra-large double be...        NaN
# ...                                                   ...        ...
# 268711  King Room1 extra-large double bedBreakfast inc...        NaN
# 268712  King Room1 extra-large double bedBreakfast inc...        NaN
# 268713  King Room with Bath Tub - Mobility Accessible/...        NaN
# 268714  King Room with Bath Tub - Mobility Accessible/...        NaN
# 268715  King Room with Bath Tub - Mobility Accessible/...        NaN
#
#                                       Scrape_hotel_Name  ... Similarity  id  \
# 0                       Millennium Biltmore Los Angeles  ...   0.800000 NaN
# 1                       Millennium Biltmore Los Angeles  ...   0.800000 NaN
# 2                     Hampton Inn & Suites Santa Monica  ...   0.571429 NaN
# 3                       Millennium Biltmore Los Angeles  ...   0.800000 NaN
# 4                     Hampton Inn & Suites Santa Monica  ...   0.571429 NaN
# ...                                                 ...  ...        ...  ..
# 268711                     Best Western Plus Fiesta Inn  ...   0.571429 NaN
# 268712                     Best Western Plus Fiesta Inn  ...   0.666667 NaN
# 268713  Best Western Plus San Antonio East Inn & Suites  ...   0.545455 NaN
# 268714  Best Western Plus San Antonio East Inn & Suites  ...   0.545455 NaN
# 268715  Best Western Plus San Antonio East Inn & Suites  ...   0.545455 NaN
#
#         bookingvalue  hotelcode  hotelname city country totalrooms  \
# 0                NaN        NaN        NaN  NaN     NaN        NaN
# 1                NaN        NaN        NaN  NaN     NaN        NaN
# 2                NaN        NaN        NaN  NaN     NaN        NaN
# 3                NaN        NaN        NaN  NaN     NaN        NaN
# 4                NaN        NaN        NaN  NaN     NaN        NaN
# ...              ...        ...        ...  ...     ...        ...
# 268711           NaN        NaN        NaN  NaN     NaN        NaN
# 268712           NaN        NaN        NaN  NaN     NaN        NaN
# 268713           NaN        NaN        NaN  NaN     NaN        NaN
# 268714           NaN        NaN        NaN  NaN     NaN        NaN
# 268715           NaN        NaN        NaN  NaN     NaN        NaN
#
#         availablerooms  profit
# 0                  NaN     NaN
# 1                  NaN     NaN
# 2                  NaN     NaN
# 3                  NaN     NaN
# 4                  NaN     NaN
# ...                ...     ...
# 268711             NaN     NaN
# 268712             NaN     NaN
# 268713             NaN     NaN
# 268714             NaN     NaN
# 268715             NaN     NaN
#
# [268716 rows x 21 columns]
